# %%
import pandas as pd
import csv
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
pd.set_option('display.max_rows', None)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(x="sepal_length", data=iris, hue="species", palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(x="sepal_width", data=iris, hue="species", palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(x="petal_length", data=iris, hue="species", palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(x="petal_width", data=iris, hue="species", palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=iris,palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris,palette={"setosa":"red","versicolor":"blue","virginica":"yellow"})
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>
