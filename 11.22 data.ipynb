# %%
import pandas as pd
import csv

# %%
ice = pd.read_csv('D:\\Python\\アイスクリーム.csv', encoding="SHIFT-JIS")
ice
# Out:
#    表章項目             世帯区分         地域区分   時間軸（月次）  /品目分類（2020年改定）  \
# 0    金額  二人以上の世帯（2000年〜）    01100 札幌市   2020年9月             NaN
# 1    金額  二人以上の世帯（2000年〜）    01100 札幌市  2020年10月             NaN
# 2    金額  二人以上の世帯（2000年〜）    01100 札幌市  2020年11月             NaN
# 3    金額  二人以上の世帯（2000年〜）    01100 札幌市  2020年12月             NaN
# 4    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年1月             NaN
# 5    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年2月             NaN
# 6    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年3月             NaN
# 7    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年4月             NaN
# 8    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年5月             NaN
# 9    金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年6月             NaN
# 10   金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年7月             NaN
# 11   金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年8月             NaN
# 12   金額  二人以上の世帯（2000年〜）    01100 札幌市   2021年9月             NaN
# 13   金額  二人以上の世帯（2000年〜）  13100 東京都区部   2020年9月             NaN
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('D:\\Python\\気象データ.csv', encoding="SHIFT-JIS")
data
# Out:
#    ダウンロードした時刻：2021/11/10 21:30:43 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                             NaN        NaN         NaN        NaN
# 1                             NaN         札幌          札幌         札幌
# 2                             NaN    平均気温(℃)  降水量の合計(mm)   日照時間(時間)
# 3                         2020年9月       20.1        53.5      140.1
# 4                        2020年10月       13.1          66      152.9
# 5                        2020年11月        6.3         113         84
# 6                        2020年12月       -1.6        26.5       95.2
# 7                         2021年1月       -4.4        90.5      109.5
# 8                         2021年2月       -2.2        78.5      114.2
# 9                         2021年3月        3.8        79.5      161.7
# 10                        2021年4月        7.9         112      207.1
# 11                        2021年5月       13.1        76.5      148.5
# 12                        2021年6月       18.9        50.5      260.7
# ...

# %%
data.describe()
# Out:
#        ダウンロードした時刻：2021/11/10 21:30:43 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# count                              13         15         15         15
# unique                             13         14         15         15
# top                           2021年5月       13.1        113      140.1
# freq                                1          2          1          1
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# count          15         15         15         15         15         15
# unique         15         15         15         15         15         15
# top          19.6         13      100.7       15.2        137      178.3
# freq            1          1          1          1          1          1
#
#        Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# count           15          15          15          15          15          15
# unique          14          15          15          15          14          15
# ...

# %%
data_f_t = data[3:16]
data_f_t
# Out:
#    ダウンロードした時刻：2021/11/10 21:30:43 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                         2020年9月       20.1       53.5      140.1       24.2
# 4                        2020年10月       13.1         66      152.9       17.5
# 5                        2020年11月        6.3        113         84         14
# 6                        2020年12月       -1.6       26.5       95.2        7.7
# 7                         2021年1月       -4.4       90.5      109.5        5.4
# 8                         2021年2月       -2.2       78.5      114.2        8.5
# 9                         2021年3月        3.8       79.5      161.7       12.8
# 10                        2021年4月        7.9        112      207.1       15.1
# 11                        2021年5月       13.1       76.5      148.5       19.6
# 12                        2021年6月       18.9       50.5      260.7       22.7
# 13                        2021年7月       23.9        7.5      285.3       25.9
# ...

# %%
average_temperature = data_f_t.iloc[0:15,[1,4,7,10,13]]
average_temperature
# Out:
#    Unnamed: 1 Unnamed: 4 Unnamed: 7 Unnamed: 10 Unnamed: 13
# 3        20.1       24.2       25.4        25.8        24.5
# 4        13.1       17.5         18        18.7        19.4
# 5         6.3         14         14        14.7        15.3
# 6        -1.6        7.7        7.4         8.7         8.5
# 7        -4.4        5.4          5         6.2           7
# 8        -2.2        8.5        7.5         8.7        10.2
# 9         3.8       12.8         12        12.2        13.5
# 10        7.9       15.1       15.2        15.5        16.7
# 11       13.1       19.6       19.5          20        20.4
# 12       18.9       22.7       23.4        23.9        24.2
# 13       23.9       25.9       27.4        27.9        28.9
# 14       22.9       27.4       27.8        28.1        27.5
# 15       18.8       22.3       24.1        24.8        25.9

# %%
average_temperature_new = average_temperature.rename(columns={'Unnamed: 1': 'sat','Unnamed: 4': 'tat','Unnamed: 7': 'nat','Unnamed: 10': 'oat','Unnamed: 13': 'fat'})
average_temperature_new
# Out:
#      sat   tat   nat   oat   fat
# 3   20.1  24.2  25.4  25.8  24.5
# 4   13.1  17.5    18  18.7  19.4
# 5    6.3    14    14  14.7  15.3
# 6   -1.6   7.7   7.4   8.7   8.5
# 7   -4.4   5.4     5   6.2     7
# 8   -2.2   8.5   7.5   8.7  10.2
# 9    3.8  12.8    12  12.2  13.5
# 10   7.9  15.1  15.2  15.5  16.7
# 11  13.1  19.6  19.5    20  20.4
# 12  18.9  22.7  23.4  23.9  24.2
# 13  23.9  25.9  27.4  27.9  28.9
# 14  22.9  27.4  27.8  28.1  27.5
# 15  18.8  22.3  24.1  24.8  25.9

# %%
average_temperature_new.dtypes
# Out:
# sat    object
# tat    object
# nat    object
# oat    object
# fat    object
# dtype: object

# %%
average_temperature_new.std(axis=0)
# Out:
# Series([], dtype: float64)

# %%
average_temperature.mean()
# Out:
# Series([], dtype: float64)

# %%
precipitation = data_f_t.iloc[0:15,[2,5,8,11,14]]
precipitation
# Out:
#    Unnamed: 2 Unnamed: 5 Unnamed: 8 Unnamed: 11 Unnamed: 14
# 3        53.5      117.5      230.5          98       310.5
# 4          66        205        269         205        64.5
# 5         113       14.5       36.5          47          25
# 6        26.5         13         22        18.5        42.5
# 7        90.5       43.5       56.5        64.5        45.5
# 8        78.5       88.5       46.5          45        79.5
# 9        79.5        173      203.5       145.5       116.5
# 10        112        156        192         224          66
# 11       76.5       99.5        254         340       133.5
# 12       50.5      168.5        137         172         123
# 13        7.5        310      312.5       268.5        45.5
# 14      108.5      382.5        347       314.5       881.5
# 15         73      222.5        224         192       246.5

# %%
precipitation_new = precipitation.rename(columns={'Unnamed: 2': 'sp','Unnamed: 5': 'tp','Unnamed: 8': 'np','Unnamed: 11': 'op','Unnamed: 14': 'fp'})
precipitation_new
# Out:
#        sp     tp     np     op     fp
# 3    53.5  117.5  230.5     98  310.5
# 4      66    205    269    205   64.5
# 5     113   14.5   36.5     47     25
# 6    26.5     13     22   18.5   42.5
# 7    90.5   43.5   56.5   64.5   45.5
# 8    78.5   88.5   46.5     45   79.5
# 9    79.5    173  203.5  145.5  116.5
# 10    112    156    192    224     66
# 11   76.5   99.5    254    340  133.5
# 12   50.5  168.5    137    172    123
# 13    7.5    310  312.5  268.5   45.5
# 14  108.5  382.5    347  314.5  881.5
# 15     73  222.5    224    192  246.5

# %%
precipitation_new.mean()
# Out:
# Series([], dtype: float64)

# %%
precipitation_new.std()
# Out:
# Series([], dtype: float64)

# %%
daylight = data_f_t.iloc[0:15,[3,6,9,12,15]]
daylight
# Out:
#    Unnamed: 3 Unnamed: 6 Unnamed: 9 Unnamed: 12 Unnamed: 15
# 3       140.1      105.7      148.5       134.6       168.2
# 4       152.9      113.9      178.2       182.8         211
# 5          84      156.6      202.5       173.2       150.1
# 6        95.2      167.9      178.3         187       131.2
# 7       109.5      172.4      161.7       176.3       118.5
# 8       114.2      214.9      164.8       189.3       173.7
# 9       161.7      193.2      192.8       194.5       186.6
# 10      207.1      218.5      219.5       221.2       214.5
# 11      148.5      150.5      151.9       169.9       179.8
# 12      260.7      131.6      153.7       173.6       187.3
# 13      285.3      160.2      175.2         191       200.8
# 14      187.4      175.6      167.1       165.2       144.9
# 15      201.2      100.7      126.1       124.9       150.3

# %%
daylight_new = daylight.rename(columns={'Unnamed: 3': 'sd','Unnamed: 6': 'td','Unnamed: 9': 'nd','Unnamed: 12': 'od','Unnamed: 15': 'fd'})
daylight_new
# Out:
#        sd     td     nd     od     fd
# 3   140.1  105.7  148.5  134.6  168.2
# 4   152.9  113.9  178.2  182.8    211
# 5      84  156.6  202.5  173.2  150.1
# 6    95.2  167.9  178.3    187  131.2
# 7   109.5  172.4  161.7  176.3  118.5
# 8   114.2  214.9  164.8  189.3  173.7
# 9   161.7  193.2  192.8  194.5  186.6
# 10  207.1  218.5  219.5  221.2  214.5
# 11  148.5  150.5  151.9  169.9  179.8
# 12  260.7  131.6  153.7  173.6  187.3
# 13  285.3  160.2  175.2    191  200.8
# 14  187.4  175.6  167.1  165.2  144.9
# 15  201.2  100.7  126.1  124.9  150.3

# %%
ice_s = ice.iloc[0:13,5]
ice_s
# Out:
# 0       938
# 1       482
# 2       513
# 3       718
# 4       614
# 5       543
# 6       651
# 7       550
# 8       610
# 9     1,065
# 10    1,417
# 11    1,426
# 12      868
# Name: 356 アイスクリーム・シャーベット【円】, dtype: object

# %%
ice_s.dtypes
# Out:
# dtype('O')

# %%
ice_t = ice.iloc[14:26,5]
ice_t
# Out:
# 14      784
# 15      682
# 16      587
# 17      509
# 18      432
# 19      550
# 20      686
# 21      889
# 22    1,014
# 23    1,282
# 24    1,385
# 25    1,053
# Name: 356 アイスクリーム・シャーベット【円】, dtype: object

# %%
ice_n = ice.iloc[27:39,5]
ice_n
# Out:
# 27      703
# 28      589
# 29      463
# 30      537
# 31      402
# 32      604
# 33      806
# 34      967
# 35    1,232
# 36    1,375
# 37    1,219
# 38    1,055
# Name: 356 アイスクリーム・シャーベット【円】, dtype: object

# %%
ice_o = ice.iloc[40:52,5]
ice_o
# Out:
# 40      548
# 41      445
# 42      568
# 43      511
# 44      531
# 45      608
# 46      798
# 47      939
# 48    1,209
# 49    1,499
# 50    1,462
# 51    1,000
# Name: 356 アイスクリーム・シャーベット【円】, dtype: object

# %%
ice_f = ice.iloc[53:65,5]
ice_f
# Out:
# 53      954
# 54      912
# 55      758
# 56      773
# 57      665
# 58      604
# 59      935
# 60    1,074
# 61    1,167
# 62    1,310
# 63    1,435
# 64    1,018
# Name: 356 アイスクリーム・シャーベット【円】, dtype: object

# %%
saporo = pd.concat([average_temperature_new['sat'], ice_s], axis=1)
saporo.dropna()
# Out:
#      sat 356 アイスクリーム・シャーベット【円】
# 3   20.1                   718
# 4   13.1                   614
# 5    6.3                   543
# 6   -1.6                   651
# 7   -4.4                   550
# 8   -2.2                   610
# 9    3.8                 1,065
# 10   7.9                 1,417
# 11  13.1                 1,426
# 12  18.9                   868

# %%
saporo = saporo.dropna()
saporo.mean()
# Out:
# Series([], dtype: float64)

# %%
saporo.std()
# Out:
# Series([], dtype: float64)

# %%
saporo.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
